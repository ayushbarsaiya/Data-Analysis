# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snn

# %%
df=pd.read_csv(r"C:\Users\hp\Downloads\winequality-red (1).csv",delimiter=';')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.size
# Out:
# 19188

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 240

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df["fixed acidity"].duplicated(keep=False).sum()
# Out:
# 1588

# %%
# leave first values , remove all duplicates
df["fixed acidity"].drop_duplicates(keep="first")
# Out:
# 0        7.4
# 1        7.8
# 3       11.2
# 6        7.9
# 7        7.3
#         ...
# 695      5.1
# 821      4.9
# 829      5.9
# 839      6.0
# 1269     5.5
# Name: fixed acidity, Length: 96, dtype: float64

# %%
# leave last values , remove all duplicates
df["fixed acidity"].drop_duplicates(keep="last")
# Out:
# 45       4.6
# 95       4.7
# 244     15.0
# 328     13.4
# 347     13.8
#         ...
# 1593     6.8
# 1594     6.2
# 1596     6.3
# 1597     5.9
# 1598     6.0
# Name: fixed acidity, Length: 96, dtype: float64

# %%
#remove all duplicates
df["fixed acidity"].drop_duplicates(keep=False)
# Out:
# 45       4.6
# 95       4.7
# 328     13.4
# 347     13.8
# 353     13.5
# 374     14.0
# 544     14.3
# 652     15.9
# 664     12.1
# 821      4.9
# 1269     5.5
# Name: fixed acidity, dtype: float64

# %%
df["fixed acidity"].unique()
# Out:
# array([ 7.4,  7.8, 11.2,  7.9,  7.3,  7.5,  6.7,  5.6,  8.9,  8.5,  8.1,
#         7.6,  6.9,  6.3,  7.1,  8.3,  5.2,  5.7,  8.8,  6.8,  4.6,  7.7,
#         8.7,  6.4,  6.6,  8.6, 10.2,  7. ,  7.2,  9.3,  8. ,  9.7,  6.2,
#         5. ,  4.7,  8.4, 10.1,  9.4,  9. ,  8.2,  6.1,  5.8,  9.2, 11.5,
#         5.4,  9.6, 12.8, 11. , 11.6, 12. , 15. , 10.8, 11.1, 10. , 12.5,
#        11.8, 10.9, 10.3, 11.4,  9.9, 10.4, 13.3, 10.6,  9.8, 13.4, 10.7,
#        11.9, 12.4, 12.2, 13.8,  9.1, 13.5, 10.5, 12.6, 14. , 13.7,  9.5,
#        12.7, 12.3, 15.6,  5.3, 11.3, 13. ,  6.5, 12.9, 14.3, 15.5, 11.7,
#        13.2, 15.9, 12.1,  5.1,  4.9,  5.9,  6. ,  5.5])

# %%
df.duplicated().sum()
# Out:
# 240

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.shape
# Out:
# (1359, 12)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1359 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1359 non-null   float64
#  1   volatile acidity      1359 non-null   float64
#  2   citric acid           1359 non-null   float64
#  3   residual sugar        1359 non-null   float64
#  4   chlorides             1359 non-null   float64
#  5   free sulfur dioxide   1359 non-null   float64
#  6   total sulfur dioxide  1359 non-null   float64
#  7   density               1359 non-null   float64
#  8   pH                    1359 non-null   float64
#  9   sulphates             1359 non-null   float64
#  10  alcohol               1359 non-null   float64
#  11  quality               1359 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 138.0 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1359.000000       1359.000000  1359.000000     1359.000000
# mean        8.310596          0.529478     0.272333        2.523400
# std         1.736990          0.183031     0.195537        1.352314
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.430000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1359.000000          1359.000000           1359.000000  1359.000000
# mean      0.088124            15.893304             46.825975     0.996709
# std       0.049377            10.447270             33.408946     0.001869
# ...

# %%
plt.figure(figsize=(12,8))
snn.heatmap(df.corr(),annot=True,cmap=snn.diverging_palette(220, 25, as_cmap=True))
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df["quality"].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
df["quality"].value_counts()
# Out:
# 5    577
# 6    535
# 7    167
# 4     53
# 8     17
# 3     10
# Name: quality, dtype: int64

# %%
snn.countplot(x=df["quality"])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
plt.pie(df["quality"].value_counts(),radius=1.7,autopct="%0.2f%%",labels=[5, 6, 7, 4, 8, 3])
plt.show()

# %%
df[df["quality"]>=7]["quality"].value_counts()
# Out:
# 7    167
# 8     17
# Name: quality, dtype: int64

# %%
plt.figure(figsize=(15,5))
snn.swarmplot(x= "quality", y="fixed acidity" ,data=df) 
plt.title('fixed acidity and quality')
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 29.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 18.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'fixed acidity and quality')

# %%
plt.figure(figsize=(15,5))
snn.boxplot(x="quality", y="fixed acidity",   data=df )
# Out:
# <AxesSubplot:xlabel='quality', ylabel='fixed acidity'>

# %%
# bar in matplotlib works on maximum value of particular column
plt.bar(df["quality"],df["fixed acidity"])
plt.xlabel("quality")
plt.ylabel("fixed acidity")
plt.title("fixed acidity Vs quality")
# Out:
# Text(0.5, 1.0, 'fixed acidity Vs quality')

# %%
df[df["quality"]==3]["fixed acidity"].max()
# Out:
# 11.6

# %%
df[df["quality"]==4]["fixed acidity"].max()
# Out:
# 12.5

# %%
df[df["quality"]==5]["fixed acidity"].max()
# Out:
# 15.9

# %%
df[df["quality"]==6]["fixed acidity"].max()
# Out:
# 14.3

# %%
df[df["quality"]==7]["fixed acidity"].max()
# Out:
# 15.6

# %%
df[df["quality"]==8]["fixed acidity"].max()
# Out:
# 12.6

# %%
df.sort_values("fixed acidity").tail(1)
# max fixed acidity----------quality 5
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 652           15.9              0.36         0.65             7.5      0.096
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 652                 22.0                  71.0   0.9976  2.98       0.84
#
#      alcohol  quality
# 652     14.9        5

# %%
df.sort_values("fixed acidity").head(1)
# min fixed acidity----------quality 4
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 45            4.6              0.52         0.15             2.1      0.054
#
#     free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 45                  8.0                  65.0   0.9934  3.9       0.56
#
#     alcohol  quality
# 45     13.1        4

# %%
# bar in matplotlib works on maximum value of particular column
plt.bar(df["quality"],df["fixed acidity"])
plt.xlabel("quality")
plt.ylabel("fixed acidity")
plt.title("fixed acidity Vs quality")
# it works on maximum value
# Out:
# Text(0.5, 1.0, 'fixed acidity Vs quality')

# %%
snn.barplot(x=df["quality"],y=df["fixed acidity"])
# barplot in snn work on mean of particular column(y-axis)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='fixed acidity'>

# %%
df.groupby('quality')['fixed acidity'].mean().plot.line()
plt.ylabel("fixed acidity")
# Out:
# Text(0, 0.5, 'fixed acidity')

# %%
df[df["quality"]==3]["fixed acidity"].mean()
# Out:
# 8.36

# %%
df[df["quality"]==4]["fixed acidity"].mean()
# Out:
# 7.779245283018868

# %%
df[df["quality"]==5]["fixed acidity"].mean()
# Out:
# 8.171230502599647

# %%
df[df["quality"]==8]["fixed acidity"].mean()
# Out:
# 8.441176470588234

# %%
plt.boxplot(df["fixed acidity"],vert=False)
plt.show()

# %%
snn.barplot(x=df["quality"],y=df["volatile acidity"])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='volatile acidity'>

# %%
df.groupby('quality')['volatile acidity'].mean().plot()
plt.ylabel("volatile acidity")
# Out:
# Text(0, 0.5, 'volatile acidity')

# %%
# plt.bar(df["quality"],df["volatile acidity"])

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
figure, axis = plt.subplots(1, 2, figsize=(12, 6))
snn.barplot(x = df["quality"], y = df["fixed acidity"], ax=axis[0])
# plt.title("quality Vs fixed acidity",loc="left")
snn.barplot(x = df["quality"], y = df["volatile acidity"], ax=axis[1])
plt.title("quality Vs volatile acidity",loc="center")
# Out:
# Text(0.5, 1.0, 'quality Vs volatile acidity')

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
snn.barplot(x=df["quality"],y=df["citric acid"])
# plt.bar(df["quality"],df["citric acid"])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='citric acid'>

# %%
# snn.lineplot(x=df["quality"],y=df["citric acid"])
df.groupby("quality")["citric acid"].mean().plot()
plt.ylabel("citric acid")
# Out:
# Text(0, 0.5, 'citric acid')

# %%
snn.barplot(x=df["quality"],y=df["residual sugar"])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='residual sugar'>

# %%
df.groupby("quality")["residual sugar"].mean().plot()
# Out:
# <AxesSubplot:xlabel='quality'>

# %%
snn.barplot(x=df["quality"],y=df["chlorides"])
# plt.bar(df["quality"],df["chlorides"])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='chlorides'>

# %%
df.groupby("quality")["chlorides"].mean().plot()
# Out:
# <AxesSubplot:xlabel='quality'>

# %%
snn.barplot(x=df["quality"],y=df["free sulfur dioxide"])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='free sulfur dioxide'>

# %%
df.groupby("quality")["free sulfur dioxide"].mean().plot()
# Out:
# <AxesSubplot:xlabel='quality'>

# %%
snn.barplot(x=df["quality"],y=df["total sulfur dioxide"])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='total sulfur dioxide'>

# %%
figure, axis = plt.subplots(1, 2, figsize=(12, 6))
snn.barplot(x = df["quality"], y = df["free sulfur dioxide"], ax=axis[0])
snn.barplot(x = df["quality"], y = df["total sulfur dioxide"], ax=axis[1])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='total sulfur dioxide'>

# %%
snn.barplot(x = df["quality"], y = df["density"])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='density'>

# %%
df.groupby("quality")["density"].mean().plot()
plt.ylabel("Density")
# Out:
# Text(0, 0.5, 'Density')

# %%
snn.barplot(x = df["quality"], y = df["pH"])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='pH'>

# %%
df.groupby("quality")["pH"].mean().plot()
# Out:
# <AxesSubplot:xlabel='quality'>

# %%
snn.boxplot(x="quality", y="pH",   data=df )
# Out:
# <AxesSubplot:xlabel='quality', ylabel='pH'>

# %%
snn.lmplot(x="fixed acidity", y="pH", data=df)

# %%
snn.barplot(x = df["quality"], y = df["sulphates"])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='sulphates'>

# %%
df.groupby("quality")["sulphates"].mean().plot()
# Out:
# <AxesSubplot:xlabel='quality'>

# %%
snn.boxplot(x="quality", y="sulphates",   data=df )
# Out:
# <AxesSubplot:xlabel='quality', ylabel='sulphates'>

# %%
snn.barplot(x = df["quality"], y = df["alcohol"])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='alcohol'>

# %%
df.groupby("quality")["alcohol"].mean().plot()
# Out:
# <AxesSubplot:xlabel='quality'>

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
figure, axis = plt.subplots(3,4, figsize=(27,10))
snn.barplot(x = df['quality'], y = df["fixed acidity"], ax=axis[0,0])
snn.barplot(x = df['quality'], y = df["volatile acidity"], ax=axis[0,1])
snn.barplot(x = df['quality'], y = df["citric acid"], ax=axis[0,2])
snn.barplot(x = df['quality'], y = df["residual sugar"], ax=axis[0,3])
snn.barplot(x = df['quality'], y = df["chlorides"], ax=axis[1,0])
snn.barplot(data=df, x='quality', y='free sulfur dioxide', ax=axis[1,1])
snn.barplot(data=df, x='quality', y='total sulfur dioxide', ax=axis[1,2])
snn.barplot(data=df, x='quality', y='density', ax=axis[1,3])
snn.barplot(data=df, x='quality', y='pH', ax=axis[2,0])
snn.barplot(data=df, x='quality', y='sulphates', ax=axis[2,1])
snn.barplot(data=df, x='quality', y='alcohol', ax=axis[2,2])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='alcohol'>

# %%
figure, axis = plt.subplots(3,4, figsize=(27,10))
snn.boxplot(x = df['quality'], y = df["fixed acidity"], ax=axis[0,0])
snn.boxplot(x = df['quality'], y = df["volatile acidity"], ax=axis[0,1])
snn.boxplot(x = df['quality'], y = df["citric acid"], ax=axis[0,2])
snn.boxplot(x = df['quality'], y = df["residual sugar"], ax=axis[0,3])
snn.boxplot(x = df['quality'], y = df["chlorides"], ax=axis[1,0])
snn.boxplot(data=df, x='quality', y='free sulfur dioxide', ax=axis[1,1])
snn.boxplot(data=df, x='quality', y='total sulfur dioxide', ax=axis[1,2])
snn.boxplot(data=df, x='quality', y='density', ax=axis[1,3])
snn.boxplot(data=df, x='quality', y='pH', ax=axis[2,0])
snn.boxplot(data=df, x='quality', y='sulphates', ax=axis[2,1])
snn.boxplot(data=df, x='quality', y='alcohol', ax=axis[2,2])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='alcohol'>

# %%
figure, axis = plt.subplots(3,4, figsize=(27,10))
snn.lineplot(x = df['quality'], y = df["fixed acidity"], ax=axis[0,0])
snn.lineplot(x = df['quality'], y = df["volatile acidity"], ax=axis[0,1])
snn.lineplot(x = df['quality'], y = df["citric acid"], ax=axis[0,2])
snn.lineplot(x = df['quality'], y = df["residual sugar"], ax=axis[0,3])
snn.lineplot(x = df['quality'], y = df["chlorides"], ax=axis[1,0])
snn.lineplot(data=df, x='quality', y='free sulfur dioxide', ax=axis[1,1])
snn.lineplot(data=df, x='quality', y='total sulfur dioxide', ax=axis[1,2])
snn.lineplot(data=df, x='quality', y='density', ax=axis[1,3])
snn.lineplot(data=df, x='quality', y='pH', ax=axis[2,0])
snn.lineplot(data=df, x='quality', y='sulphates', ax=axis[2,1])
snn.lineplot(data=df, x='quality', y='alcohol', ax=axis[2,2])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='alcohol'>

# %%
# snn.pairplot(df)

# %%
snn.pairplot(df, vars = ['sulphates','alcohol','quality'])

# %% [markdown]
# # REPORT

# %%
# less volatile acidity more quality.
# more citric acide best quality.
# less chloride more quality
# the amount of alchol is incresing, the quality of wine is incresing.
# more sulphates is good quality.
# less pH and density more quality.
