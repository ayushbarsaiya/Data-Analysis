# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snn

# %%
df=pd.read_csv(r"C:\Users\hp\Downloads\titanic_data.csv")
df.head()
# Out:
#    PassengerId  Survived Pclass                                          Name  \
# 0          892         0      3                              Kelly, Mr. James
# 1          893         1      3              Wilkes, Mrs. James (Ellen Needs)
# 2          894         0      @                     Myles, Mr. Thomas Francis
# 3          895         0      3                              Wirz, Mr. Albert
# 4          896         1      3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#
#       Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0    male  34.5      0      0   330911   7.8292   NaN        Q
# 1  female  47.0      1      0   363272   7.0000   NaN        S
# 2    male  62.0      0      0   240276   9.6875   NaN        Q
# 3    male  27.0      0      0   315154   8.6625   NaN        S
# 4  female  22.0      1      1  3101298  12.2875   NaN        S

# %%
df.shape
# Out:
# (418, 12)

# %%
df.size
# Out:
# 5016

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    object
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 39.3+ KB

# %%
# it represent the null vales
snn.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
# corr represent the relationship between feature and feature
snn.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df["Cabin"]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 413     NaN
# 414    C105
# 415     NaN
# 416     NaN
# 417     NaN
# Name: Cabin, Length: 418, dtype: object

# %%
null_Cabin=df["Cabin"].isnull().sum()

# %%
shape=df.shape
shape
# Out:
# (418, 12)

# %%
per_null_Cabin=(null_Cabin/shape[0])*100
per_null_Cabin
# Out:
# 78.22966507177034

# %%
df
# Out:
#      PassengerId  Survived Pclass  \
# 0            892         0      3
# 1            893         1      3
# 2            894         0      @
# 3            895         0      3
# 4            896         1      3
# ..           ...       ...    ...
# 413         1305         0      3
# 414         1306         1      1
# 415         1307         0      3
# 416         1308         0      3
# 417         1309         0      3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# ...

# %%
# there are 78.229 ~ 80 % null values than we drop the cabin column
df.drop("Cabin",axis=1,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived Pclass  \
# 0            892         0      3
# 1            893         1      3
# 2            894         0      @
# 3            895         0      3
# 4            896         1      3
# ..           ...       ...    ...
# 413         1305         0      3
# 414         1306         1      1
# 415         1307         0      3
# 416         1308         0      3
# 417         1309         0      3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# ...

# %%
df["Survived"].sum()
# Out:
# 152

# %%
# all female are survied but no man is survied
plt.bar("Sex","Survived",data=df,color="m")
# Out:
# <BarContainer object of 418 artists>

# %%
plt.pie(df["Sex"].value_counts(),labels=["male","female"],autopct="%0.2f%%")
# male is more than the female
# Out:
# ([<matplotlib.patches.Wedge at 0x1dd2c225b20>,
# ...
#  [Text(-0.45695648023571717, 1.000595210447554, 'male'),
#   Text(0.4569564802357173, -1.000595210447554, 'female')],
#  [Text(-0.24924898921948208, 0.5457792056986657, '63.64%'),
#   Text(0.24924898921948213, -0.5457792056986657, '36.36%')])

# %%
plt.pie(df["Embarked"].value_counts(),labels=["s","c","Q"],autopct="%0.3f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1dd2c27a310>,
# ...
#  [Text(-0.4868265385090287, 0.9864075838127551, 's'),
#   Text(0.12374782917019257, -1.0930171429468365, 'c'),
#   Text(1.0349128595987116, -0.37276718342313564, 'Q')],
#  [Text(-0.265541748277652, 0.5380405002615027, '64.593%'),
#   Text(0.06749881591101412, -0.5961911688800925, '24.402%'),
#   Text(0.564497923417479, -0.2033275545944376, '11.005%')])

# %%
df["Fare"].max()
# The maximum fare is 512.32
# Out:
# 512.3292

# %%
df["Fare"].min()
# The minimum fare is 0.0
# Out:
# 0.0

# %%
snn.displot(df["Fare"])

# %%
df.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Ticket          0
# Fare            1
# Embarked        0
# dtype: int64

# %%
snn.scatterplot(x="PassengerId",y="Age",hue="Sex",data=df)
# Out:
# <AxesSubplot:xlabel='PassengerId', ylabel='Age'>

# %%
df["Age"]
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
df["Age"].mean()
# Out:
# 30.272590361445783

# %%
df["Age"].median()
# Out:
# 27.0

# %%
df["Age"].mode()
# Out:
# 0    21.0
# 1    24.0
# Name: Age, dtype: float64

# %%
df["Age"].fillna(df["Age"].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           1
# Embarked       0
# dtype: int64

# %%
df["Pclass"]
# Out:
# 0      3
# 1      3
# 2      @
# 3      3
# 4      3
#       ..
# 413    3
# 414    1
# 415    3
# 416    3
# 417    3
# Name: Pclass, Length: 418, dtype: object

# %%
df["Pclass"].unique()
# Out:
# array(['3', '@', '2', '1'], dtype=object)

# %%
df["Pclass"].value_counts()
# Out:
# 3    218
# 1    107
# 2     92
# @      1
# Name: Pclass, dtype: int64

# %%
df["Pclass"].mode()
# Out:
# 0    3
# Name: Pclass, dtype: object

# %%
df["Pclass"].replace(to_replace='@',value=df["Pclass"].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           1
# Embarked       0
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived Pclass  \
# 0            892         0      3
# 1            893         1      3
# 2            894         0      3
# 3            895         0      3
# 4            896         1      3
# ..           ...       ...    ...
# 413         1305         0      3
# 414         1306         1      1
# 415         1307         0      3
# 416         1308         0      3
# 417         1309         0      3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# ...

# %%
df["Embarked"].unique()
# Out:
# array(['Q', 'S', 'C'], dtype=object)

# %%
df["Embarked"].value_counts()
# Out:
# S    270
# C    102
# Q     46
# Name: Embarked, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    object
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          418 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
df["Pclass"].unique()
# Out:
# array(['3', '2', '1'], dtype=object)

# %%
df["Pclass"]=df["Pclass"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int32
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          418 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int32(1), int64(4), object(4)
# memory usage: 34.4+ KB

# %%
# from sklearn.preprocessing import OneHotEncoder
# ob=OneHotEncoder()

# %%
a=pd.get_dummies(data=df,columns=["Sex"])
a
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       3
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  47.0      1      0
# 2                       Myles, Mr. Thomas Francis  62.0      0      0
# 3                                Wirz, Mr. Albert  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0      1      1
# ..                                            ...   ...    ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       3
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df["sex"]=a["Sex_female"]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       3
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#  male=0 , female=1

# %%
df.drop("Sex",axis=1,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       3
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  47.0      1      0
# 2                       Myles, Mr. Thomas Francis  62.0      0      0
# 3                                Wirz, Mr. Albert  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0      1      1
# ..                                            ...   ...    ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int32
#  3   Name         418 non-null    object
#  4   Age          418 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Embarked     418 non-null    object
#  10  sex          418 non-null    uint8
# dtypes: float64(2), int32(1), int64(4), object(3), uint8(1)
# memory usage: 31.6+ KB

# %%
pd.get_dummies(data=df,columns=["Embarked"])
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       3
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  47.0      1      0
# 2                       Myles, Mr. Thomas Francis  62.0      0      0
# 3                                Wirz, Mr. Albert  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0      1      1
# ..                                            ...   ...    ...    ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder
md=LabelEncoder()

# %%
embarked=md.fit_transform(df["Embarked"])

# %%
df["embarked"]=embarked

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       3
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  47.0      1      0
# 2                       Myles, Mr. Thomas Francis  62.0      0      0
# 3                                Wirz, Mr. Albert  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0      1      1
# ..                                            ...   ...    ...    ...
# ...

# %%
df.drop("Embarked",axis=1,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       3
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  47.0      1      0
# 2                       Myles, Mr. Thomas Francis  62.0      0      0
# 3                                Wirz, Mr. Albert  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0      1      1
# ..                                            ...   ...    ...    ...
# ...

# %%
name=md.fit_transform(df["Name"])

# %%
df["name"]=name

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       3
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  47.0      1      0
# 2                       Myles, Mr. Thomas Francis  62.0      0      0
# 3                                Wirz, Mr. Albert  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0      1      1
# ..                                            ...   ...    ...    ...
# ...

# %%
df.drop("Name",axis=1,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch              Ticket  \
# 0            892         0       3  34.5      0      0              330911
# 1            893         1       3  47.0      1      0              363272
# 2            894         0       3  62.0      0      0              240276
# 3            895         0       3  27.0      0      0              315154
# 4            896         1       3  22.0      1      1             3101298
# ..           ...       ...     ...   ...    ...    ...                 ...
# 413         1305         0       3  27.0      0      0           A.5. 3236
# 414         1306         1       1  39.0      0      0            PC 17758
# 415         1307         0       3  38.5      0      0  SOTON/O.Q. 3101262
# 416         1308         0       3  27.0      0      0              359309
# 417         1309         0       3  27.0      1      1                2668
#
#          Fare  sex  embarked  name
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int32
#  3   Age          418 non-null    float64
#  4   SibSp        418 non-null    int64
#  5   Parch        418 non-null    int64
#  6   Ticket       418 non-null    object
#  7   Fare         417 non-null    float64
#  8   sex          418 non-null    uint8
#  9   embarked     418 non-null    int32
#  10  name         418 non-null    int32
# dtypes: float64(2), int32(3), int64(4), object(1), uint8(1)
# memory usage: 28.3+ KB

# %%
df.describe().T
# Out:
#              count         mean         std     min       25%        50%  \
# PassengerId  418.0  1100.500000  120.810458  892.00  996.2500  1100.5000
# Survived     418.0     0.363636    0.481622    0.00    0.0000     0.0000
# Pclass       418.0     2.267943    0.842502    1.00    1.0000     3.0000
# Age          418.0    29.599282   12.703770    0.17   23.0000    27.0000
# SibSp        418.0     0.447368    0.896760    0.00    0.0000     0.0000
# Parch        418.0     0.392344    0.981429    0.00    0.0000     0.0000
# Fare         417.0    35.627188   55.907576    0.00    7.8958    14.4542
# sex          418.0     0.363636    0.481622    0.00    0.0000     0.0000
# embarked     418.0     1.401914    0.854496    0.00    1.0000     2.0000
# name         418.0   208.500000  120.810458    0.00  104.2500   208.5000
#
#                  75%        max
# PassengerId  1204.75  1309.0000
# Survived        1.00     1.0000
# Pclass          3.00     3.0000
# Age            35.75    76.0000
# ...

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.023245 -0.031595 -0.031447  0.003818  0.043080
# Survived       -0.023245  1.000000 -0.110678  0.008035  0.099943  0.159120
# Pclass         -0.031595 -0.110678  1.000000 -0.460224 -0.000334  0.017568
# Age            -0.031447  0.008035 -0.460224  1.000000 -0.071197 -0.043731
# SibSp           0.003818  0.099943 -0.000334 -0.071197  1.000000  0.306895
# Parch           0.043080  0.159120  0.017568 -0.043731  0.306895  1.000000
# Fare            0.008211  0.191514 -0.578011  0.347105  0.171539  0.230046
# sex            -0.023245  1.000000 -0.110678  0.008035  0.099943  0.159120
# embarked        0.040699 -0.076281  0.226464 -0.148051  0.052708  0.054577
# name            0.042079 -0.067263  0.040312 -0.032388  0.043994 -0.010295
#
#                  Fare       sex  embarked      name
# PassengerId  0.008211 -0.023245  0.040699  0.042079
# ...

# %% [markdown]
# # Report

# %%
# I have titanic dataset which have multiple column
# first we check the null values
# we find the Cabin column has aprox 80% null value than we remove this column
# and we do some visulization such as pieplot with Sex and also with Embarked
# we make a barplot of sex which denote the female only survived
# we do some experiment with fare and we find the max fare is approx 500 and min fare is almost 0
# I also make a scatter which denote the relationship with PassengerId and Age with respect to Sex
# and we handdle sum categorical values with label encoder or get dummies
